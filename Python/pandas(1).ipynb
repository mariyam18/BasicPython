# %%
import pandas as pd

# %%
country_data ={'country': ['india', 'USA', 'afria'], 'population': [1.3, 45, 3.4]}

# %%
type(country_data)
# Out:
# dict

# %%
df=pd.DataFrame(country_data)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#   country  population
# 0   india         1.3
# 1     USA        45.0
# 2   afria         3.4

# %%
df['capital']=['delhi','london','bj']

# %%
df
# Out:
#   country  population capital
# 0   india         1.3   delhi
# 1     USA        45.0  london
# 2   afria         3.4      bj

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df[['country','capital']]
# Out:
#   country capital
# 0   india   delhi
# 1     USA  london
# 2   afria      bj

# %%
df['president']=['jk','sd','ds']

# %%
df
# Out:
#   country  population capital president
# 0   india         1.3   delhi        jk
# 1     USA        45.0  london        sd
# 2   afria         3.4      bj        ds

# %%
df['money']=[2500,5980,546210]

# %%
df
# Out:
#   country  population capital president   money
# 0   india         1.3   delhi        jk    2500
# 1     USA        45.0  london        sd    5980
# 2   afria         3.4      bj        ds  546210

# %%
df['add']=df['population']+df['money']

# %%
df
# Out:
#   country  population capital president   money       add
# 0   india         1.3   delhi        jk    2500    2501.3
# 1     USA        45.0  london        sd    5980    6025.0
# 2   afria         3.4      bj        ds  546210  546213.4

# %%
df['str']=df['country']+df['capital']

# %%
df
# Out:
#   country  population capital president   money       add         str
# 0   india         1.3   delhi        jk    2500    2501.3  indiadelhi
# 1     USA        45.0  london        sd    5980    6025.0   USAlondon
# 2   afria         3.4      bj        ds  546210  546213.4     afriabj

# %%
df.set_index('country',inplace=True)

# %%
loc['india']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f6feae9b58b8> in <module>()
# ----> 1 loc['india']
#
# NameError: name 'loc' is not defined

# %%
df.iloc[0]
# Out:
# country            india
# population           1.3
# capital            delhi
# president             jk
# money               2500
# add               2501.3
# str           indiadelhi
# Name: 0, dtype: object

# %%
df
# Out:
#   country  population capital president   money       add         str
# 0   india         1.3   delhi        jk    2500    2501.3  indiadelhi
# 1     USA        45.0  london        sd    5980    6025.0   USAlondon
# 2   afria         3.4      bj        ds  546210  546213.4     afriabj

# %%
df.loc[0]
# Out:
# country            india
# population           1.3
# capital            delhi
# president             jk
# money               2500
# add               2501.3
# str           indiadelhi
# Name: 0, dtype: object

# %%
df
# Out:
#          population capital president   money       add         str
# country
# india           1.3   delhi        jk    2500    2501.3  indiadelhi
# USA            45.0  london        sd    5980    6025.0   USAlondon
# afria           3.4      bj        ds  546210  546213.4     afriabj

# %%
df.loc['india']
# Out:
# population           1.3
# capital            delhi
# president             jk
# money               2500
# add               2501.3
# str           indiadelhi
# Name: india, dtype: object

# %%
df.iloc[2]
# Out:
# population        3.4
# capital            bj
# president          ds
# money          546210
# add            546213
# str           afriabj
# Name: afria, dtype: object

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-7eaf75073732> in <module>()
# ----> 1 df.loc[0]
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1624
#    1625         # fall thru to straight lookup
# -> 1626         self._has_valid_type(key, axis)
#    1627         return self._get_label(key, axis=axis)
#    1628
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1502
#    1503             try:
# ...

# %%
df.drop('india')
# Out:
#          population capital president   money       add        str
# country
# USA            45.0  london        sd    5980    6025.0  USAlondon
# afria           3.4      bj        ds  546210  546213.4    afriabj

# %%
df.drop('str',axis=1)
# Out:
#          population capital president   money       add
# country
# india           1.3   delhi        jk    2500    2501.3
# USA            45.0  london        sd    5980    6025.0
# afria           3.4      bj        ds  546210  546213.4

# %%
df
# Out:
#          population capital president   money       add         str
# country
# india           1.3   delhi        jk    2500    2501.3  indiadelhi
# USA            45.0  london        sd    5980    6025.0   USAlondon
# afria           3.4      bj        ds  546210  546213.4     afriabj

# %%
df.drop('str',axis=1,inplace=True)

# %%
df
# Out:
#          population capital president   money       add
# country
# india           1.3   delhi        jk    2500    2501.3
# USA            45.0  london        sd    5980    6025.0
# afria           3.4      bj        ds  546210  546213.4

# %%
df['population']>1.2
# Out:
# country
# india    True
# USA      True
# afria    True
# Name: population, dtype: bool

# %%
df['money']>2500
# Out:
# country
# india    False
# USA       True
# afria     True
# Name: money, dtype: bool

# %%
df[df['population']>1.3]
# Out:
#          population capital president   money       add
# country
# USA            45.0  london        sd    5980    6025.0
# afria           3.4      bj        ds  546210  546213.4

# %%
df[df['money']>2500]['capital']
# Out:
# country
# USA      london
# afria        bj
# Name: capital, dtype: object

# %%
df
# Out:
#          population capital president   money       add
# country
# india           1.3   delhi        jk    2500    2501.3
# USA            45.0  london        sd    5980    6025.0
# afria           3.4      bj        ds  546210  546213.4

# %%
df[df['money']>5980][['population','add']]
# Out:
#          population       add
# country
# afria           3.4  546213.4

# %%
df[(df['population']>3.4)&(df['money']>2500)]
# Out:
#          population capital president  money     add
# country
# USA            45.0  london        sd   5980  6025.0

# %%
df
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2009-12-31  10.04  10.06   9.92  10.00   7.880220   31253700
# 2010-01-04  10.17  10.28  10.05  10.28   8.100866   60855800
# 2010-01-05  10.45  11.24  10.40  10.96   8.636724  215620200
# 2010-01-06  11.21  11.46  11.13  11.37   8.959811  200070600
# 2010-01-07  11.46  11.69  11.32  11.66   9.188335  130201700
# 2010-01-08  11.67  11.74  11.46  11.69   9.211980  130463000
# 2010-01-11  11.90  12.14  11.78  12.11   9.542947  170626200
# 2010-01-12  11.98  12.03  11.72  11.87   9.353823  162995900
# 2010-01-13  11.91  11.93  11.47  11.68   9.204099  154527100
# 2010-01-14  11.65  11.86  11.51  11.76   9.267142  116531200
# 2010-01-15  11.74  11.76  11.55  11.60   9.141056   96149800
# 2010-01-19  11.51  11.83  11.46  11.75   9.259260   65934000
# 2010-01-20  11.68  11.69  11.50  11.51   9.070133   71649500
# 2010-01-21  11.53  11.62  11.01  11.18   8.810086  121451400
# ...

# %%
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7cc7b4a4e896> in <module>()
#       1 df['Open'].plot()
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
data={'A':[1,2,np.nan],'B':[5,np.nan,2],'c':[1,2,3]}

# %%
data
# Out:
# {'A': [1, 2, nan], 'B': [5, nan, 2], 'c': [1, 2, 3]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  2.0  3

# %%
df.drop(1)
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 2  NaN  2.0  3

# %%
df.dropna()
# Out:
#      A    B  c
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  2.0  3

# %%
df.dropna(axis=0)
# Out:
#      A    B  c
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    c
# 0  1
# 1  2
# 2  3

# %%
df.fillna(value='8')
# Out:
#    A  B  c
# 0  1  5  1
# 1  2  8  2
# 2  8  2  3

# %%
df.fillna(value=df['B'].min())
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  2.0  2
# 2  2.0  2.0  3

# %%
df['A'].fillna(value=df['A'].min())
# Out:
# 0    1.0
# 1    2.0
# 2    1.0
# Name: A, dtype: float64

# %%
df['B'].fillna(value=df['B'].max())
# Out:
# 0    5.0
# 1    5.0
# 2    2.0
# Name: B, dtype: float64

# %%
df['B'].fillna(value=df['B'].mean())
# Out:
# 0    5.0
# 1    3.5
# 2    2.0
# Name: B, dtype: float64

# %%
df['B'].fillna(value=df['B'].median())
# Out:
# 0    5.0
# 1    3.5
# 2    2.0
# Name: B, dtype: float64

# %%
df['B'].fillna(value=np.random.randint(100))
# Out:
# 0     5.0
# 1    35.0
# 2     2.0
# Name: B, dtype: float64

# %%
df.fillna(df.mean())
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  3.5  2
# 2  1.5  2.0  3

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

# %%
df['Open']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-44742b198aba> in <module>()
# ----> 1 df['Open']
#
# NameError: name 'df' is not defined

# %%
import pandas_datareader.data as web
import datetime

# %%
start= datetime.datetime(2010,1,1)
end=datetime.datetime(2017,12,27)

df=web.DataReader("F",'yahoo',start,end)

# %%
df
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2009-12-31  10.04  10.06   9.92  10.00   7.880220   31253700
# 2010-01-04  10.17  10.28  10.05  10.28   8.100866   60855800
# 2010-01-05  10.45  11.24  10.40  10.96   8.636724  215620200
# 2010-01-06  11.21  11.46  11.13  11.37   8.959811  200070600
# 2010-01-07  11.46  11.69  11.32  11.66   9.188335  130201700
# 2010-01-08  11.67  11.74  11.46  11.69   9.211980  130463000
# 2010-01-11  11.90  12.14  11.78  12.11   9.542947  170626200
# 2010-01-12  11.98  12.03  11.72  11.87   9.353823  162995900
# 2010-01-13  11.91  11.93  11.47  11.68   9.204099  154527100
# 2010-01-14  11.65  11.86  11.51  11.76   9.267142  116531200
# 2010-01-15  11.74  11.76  11.55  11.60   9.141056   96149800
# 2010-01-19  11.51  11.83  11.46  11.75   9.259260   65934000
# 2010-01-20  11.68  11.69  11.50  11.51   9.070133   71649500
# 2010-01-21  11.53  11.62  11.01  11.18   8.810086  121451400
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

# %%
df['Open'].plot()
plt.show()

# %%
df['Close'].plot()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import pandas as pd
df=pd.read_csv('indiacencesdata.csv')

# %%
df
# Out:
#     Year  Population
# 0   1950         370
# 1   1951         376
# 2   1952         383
# 3   1953         390
# 4   1954         397
# 5   1955         404
# 6   1956         412
# 7   1957         420
# 8   1958         428
# 9   1959         437
# 10  1960         446
# 11  1961         455
# 12  1962         464
# 13  1963         474
# 14  1964         485
# 15  1965         496
# 16  1966         507
# 17  1967         519
# 18  1968         530
# 19  1969         543
# 20  1970         555
# 21  1971         568
# 22  1972         581
# 23  1973         595
# 24  1974         608
# 25  1975         622
# 26  1976         636
# 27  1977         649
# 28  1978         663
# 29  1979         676
# 30  1980         690
# 31  1981         705
# 32  1982         720
# 33  1983         736
# 34  1984         752
# 35  1985         768
# 36  1986         784
# 37  1987         801
# 38  1988         817
# 39  1989         834
# 40  1990         851
# 41  1991         867
# ...

# %%
df.set_index('Year',inplace=True)

# %%
df
# Out:
#       Population
# Year
# 1950         370
# 1951         376
# 1952         383
# 1953         390
# 1954         397
# 1955         404
# 1956         412
# 1957         420
# 1958         428
# 1959         437
# 1960         446
# 1961         455
# 1962         464
# 1963         474
# 1964         485
# 1965         496
# 1966         507
# 1967         519
# 1968         530
# 1969         543
# 1970         555
# 1971         568
# 1972         581
# 1973         595
# 1974         608
# 1975         622
# 1976         636
# 1977         649
# 1978         663
# 1979         676
# 1980         690
# 1981         705
# 1982         720
# 1983         736
# 1984         752
# 1985         768
# 1986         784
# 1987         801
# 1988         817
# 1989         834
# 1990         851
# 1991         867
# 1992         883
# 1993         899
# 1994         916
# 1995         932
# 1996         949
# 1997         965
# 1998         982
# 1999         998

# %%
df['Population'].plot()
plt.show()

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
df['OvertimePay'],df.fillna(value=df['OvertimePay'].mean(),inplace=True)
# Out:
# (0              0.000000
#  1         245131.880000
#  2         106088.180000
#  3          56120.710000
#  4           9737.000000
#  5           8601.000000
#  6          89062.900000
#  7              0.000000
#  8          86362.680000
#  9              0.000000
#  10         71344.880000
#  11         87082.620000
#  12             0.000000
#  13             0.000000
#  14         74050.300000
#  15         73478.200000
#  16             0.000000
#  17        119397.260000
#  18         69626.120000
#  19           880.160000
#  20             0.000000
#  21           377.210000
#  22         93200.580000
#  23         77896.140000
#  24         97868.770000
#  25             0.000000
#  26         40008.000000
#  27         80706.880000
#  28             0.000000
#  29             0.000000
#                ...
#  148624         0.000000
#  148625         0.000000
#  148626         0.000000
#  148627         0.000000
#  148628         0.000000
#  148629         0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148654 non-null float64
# OvertimePay         148654 non-null float64
# OtherPay            148654 non-null float64
# Benefits            148654 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               148654 non-null float64
# Agency              148654 non-null object
# Status              148654 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
df['BasePay'].mean()
# Out:
# 66074.4837277224

# %%
df[df['BasePay'].min()==df['BasePay']]['EmployeeName']
# Out:
# 72832    Irwin Sidharta
# Name: EmployeeName, dtype: object

# %%
df[df['EmployeeName']=='NATHANIEL FORD']['TotalPay']
# Out:
# 0    567595.43
# Name: TotalPay, dtype: float64

# %%
df[df['TotalPayBenefits'].max()==df['TotalPayBenefits']]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
df[df['TotalPayBenefits'].min()==df['TotalPayBenefits']]['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
df.loc[df['TotalPayBenefits'].argmin()]
# Out:
# /home/codept/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   """Entry point for launching an IPython kernel.
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                      0
# OvertimePay                                  0
# OtherPay                               -618.13
# Benefits                                     0
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Notes                                  5066.06
# Agency                           San Francisco
# Status                                 5066.06
# ...

# %% [markdown]
# sum(df[df['Year']==2013]['JobTitle'].value_counts()==1)

# %%
ecom=pd.read_csv('Ecommerce Purchases.csv')

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
ecom[ecom['Purchase Price'].max()==ecom['Purchase Price']]['Company']
# Out:
# 2092                  Pitts Group
# 7807    Porter, Johnson and Pratt
# Name: Company, dtype: object

# %% [markdown]
# ecom[ecom['Language']=='en']['Language'].counts()

# %%
ecom[ecom['Language']=='en']['Language'].counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-a8512bbb87f6> in <module>()
# ----> 1 ecom[ecom['Language']=='en']['Language'].counts()
#
# ~/.local/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'counts'

# %%
ecom['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
ecom['Job'].value_counts().head(6)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Purchasing manager                   27
# Research officer, political party    27
# Designer, jewellery                  27
# Name: Job, dtype: int64

# %%
ecom[ecom['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
ecom[ecom['Credit Card']==4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
len(ecom[(ecom['Purchase Price']>95) & (ecom['CC Provider']=='American Express')])
# Out:
# 39
